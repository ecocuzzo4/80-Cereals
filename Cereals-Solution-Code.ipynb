# %% [markdown]
# # Welcome!

# %% [markdown]
# This is your introduction to Python. Today, we will be using a very small dataset focused on cereals.

# %% [markdown]
# ## Load the Pandas

# %% [markdown]
# Pandas is a Python library that primarily adds two new datatypes to Python: DataFrame and Series.
#
#     A Series is a sequence of items, where each item has a unique label (called an index).
#
#     A DataFrame is a table of data. Each row has a unique label (the row index), and each column has a unique label (the column index)

# %%
# Load pandas into python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Import the Data

# %% [markdown]
# First, it's important to find your location.

# %%
pwd
# Out:
# '/Users/emileecocuzzo/Documents/DataScience/Cereals'

# %%
# Import the dataset
df = pd.read_csv('/Users/emileecocuzzo/Documents/DataScience/Cereals/cereal.csv')
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# Now that you have the data imported, it's time to explore the dataset.

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
# DataFrame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Find the Count, Mean, Standard Deviation, Min., Max., %
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
# Find all the column names
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
# Print the first 5 rows
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# Data types of each column -- each column is stored as an ndarray which has a data type
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
# Total number of rows and columns
df.shape
# Out:
# (77, 16)

# %%
# Finding the missing values
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# ## Data Visualizations

# %%
# Draw a histogram of a column (the distribution of ratings)
df.rating.hist();

# %% [markdown]
# ## Practice Exercise

# %%
# How many total number of rows and columns?

# %%
# Answer: (77, 16)
df.shape
# Out:
# (77, 16)

# %%
# Find all cereals with sodium < 150
df[df.sodium < 150]
# Out:
#                                 name mfr type  calories  protein  fat  sodium  \
# 0                          100% Bran   N    C        70        4    1     130
# 1                  100% Natural Bran   Q    C       120        3    5      15
# 3          All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                        Apple Jacks   K    C       110        2    0     125
# 13                          Clusters   G    C       110        3    2     140
# 17                         Corn Pops   K    C       110        1    0      90
# 19                Cracklin' Oat Bran   K    C       110        3    3     140
# 20            Cream of Wheat (Quick)   N    H       100        3    0      80
# 22            Crispy Wheat & Raisins   G    C       100        2    1     140
# 24                       Froot Loops   K    C       110        2    1     125
# 26               Frosted Mini-Wheats   K    C       100        3    0       0
# 29                    Fruity Pebbles   P    C       110        1    1     135
# 30                      Golden Crisp   P    C       100        2    0      45
# 32                 Grape Nuts Flakes   P    C       100        3    1     140
# 34                Great Grains Pecan   P    C       120        3    3      75
# 43                             Maypo   A    H       100        4    1       0
# 44  Muesli Raisins; Dates; & Almonds   R    C       150        4    3      95
# 54                       Puffed Rice   Q    C        50        1    0       0
# 55                      Puffed Wheat   Q    C        50        2    0       0
# 56                Quaker Oat Squares   Q    C       100        4    1     135
# 57                    Quaker Oatmeal   Q    H       100        5    2       0
# 59                   Raisin Nut Bran   G    C       100        3    2     140
# 60                    Raisin Squares   K    C        90        2    0       0
# 63                    Shredded Wheat   N    C        80        2    0       0
# 64            Shredded Wheat 'n'Bran   N    C        90        3    0       0
# 65         Shredded Wheat spoon size   N    C        90        3    0       0
# 66                            Smacks   K    C       110        2    1      70
# 68           Strawberry Fruit Wheats   N    C        90        2    0      15
# 73                              Trix   G    C       110        1    1     140
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    10.0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1     2.0    8.0       8     135         0      3    1.00  1.00  33.983679
# 3    14.0    8.0       0     330        25      3    1.00  0.50  93.704912
# 6     1.0   11.0      14      30        25      2    1.00  1.00  33.174094
# 13    2.0   13.0       7     105        25      3    1.00  0.50  40.400208
# 17    1.0   13.0      12      20        25      2    1.00  1.00  35.782791
# 19    4.0   10.0       7     160        25      3    1.00  0.50  40.448772
# 20    1.0   21.0       0      -1         0      2    1.00  1.00  64.533816
# 22    2.0   11.0      10     120        25      3    1.00  0.75  36.176196
# 24    1.0   11.0      13      30        25      2    1.00  1.00  32.207582
# 26    3.0   14.0       7     100        25      2    1.00  0.80  58.345141
# 29    0.0   13.0      12      25        25      2    1.00  0.75  28.025765
# 30    0.0   11.0      15      40        25      1    1.00  0.88  35.252444
# 32    3.0   15.0       5      85        25      3    1.00  0.88  52.076897
# 34    3.0   13.0       4     100        25      3    1.00  0.33  45.811716
# 43    0.0   16.0       3      95        25      2    1.00  1.00  54.850917
# 44    3.0   16.0      11     170        25      3    1.00  1.00  37.136863
# 54    0.0   13.0       0      15         0      3    0.50  1.00  60.756112
# 55    1.0   10.0       0      50         0      3    0.50  1.00  63.005645
# 56    2.0   14.0       6     110        25      3    1.00  0.50  49.511874
# 57    2.7   -1.0      -1     110         0      1    1.00  0.67  50.828392
# 59    2.5   10.5       8     140        25      3    1.00  0.50  39.703400
# 60    2.0   15.0       6     110        25      3    1.00  0.50  55.333142
# 63    3.0   16.0       0      95         0      1    0.83  1.00  68.235885
# 64    4.0   19.0       0     140         0      1    1.00  0.67  74.472949
# 65    3.0   20.0       0     120         0      1    1.00  0.67  72.801787
# 66    1.0    9.0      15      40        25      2    1.00  0.75  31.230054
# 68    3.0   15.0       5      90        25      2    1.00  1.00  59.363993
# 73    0.0   13.0      12      25        25      2    1.00  1.00  27.753301

# %%
# Print the first 5 rows
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# Plot a chart of Calories vs. Ratings
df.calories.value_counts().sort_index().plot(kind='bar', figsize=(12,12));     
plt.xlabel('calories');
plt.ylabel('ratings');
plt.title('Ratings by Calories');

# %%
# Are there any missing values? If so, how many?

# %%
# Answer: No
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
# What is the average rating

# %%
# Answer: 42.665705
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %% [markdown]
# Congrats! You have successfully completed the first step of Python. Now, go practice!
